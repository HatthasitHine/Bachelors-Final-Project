# %%
import json
import os
import subprocess
import wave
from pydub import AudioSegment
from google.cloud import speech
from pythainlp.util import Trie
from spleeter.separator import Separator
from pythainlp.tokenize import word_tokenize
import gc

# %%
# ฟังก์ชั่นสำหรับแปลงไฟล์ .mp3 เป็น .wav
def convert_mp3_to_wav(file_path):
    if file_path.endswith('.mp3'):
        new_file_path = file_path[:-4] + '.wav'  # เปลี่ยนนามสกุลไฟล์

        # ตรวจสอบว่าไฟล์ .wav มีอยู่แล้วหรือไม่
        if not os.path.exists(new_file_path):
            # ใช้ ffmpeg เพื่อแปลงไฟล์
            command = f'ffmpeg -i "{file_path}" -acodec pcm_s16le -ar 44100 "{new_file_path}"' # 16000 44100 22050 48000
            result = subprocess.run(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            
            if result.returncode != 0:
                print(f"Error converting {file_path} to {new_file_path}:\n{result.stderr.decode('utf-8')}")
                return None
            
            print(f'Converted: {file_path} to {new_file_path}')
        else:
            print(f'File already exists: {new_file_path}')
        return new_file_path
    return file_path

# %%
# ฟังก์ชั่นสำหรับแยกเสียงร้องออกจากเพลงโดยใช้ Spleeter
def separate_vocals(input_file):
    output_dir = os.path.dirname(input_file)
    base_name = os.path.splitext(os.path.basename(input_file))[0]
    
    separator = Separator('spleeter:2stems')
    separator.separate_to_file(input_file, output_dir)
    
    vocals_path = os.path.join(output_dir, base_name, 'vocals.wav')
    new_vocals_path = os.path.join(output_dir, f'{base_name}_vocals.wav')
    
    if not os.path.exists(vocals_path):
        print(f"Failed to separate vocals for file: {input_file}")
        return None

    os.rename(vocals_path, new_vocals_path)

    # ลบไฟล์ต้นฉบับและไฟล์ที่ไม่ต้องการ
    accompaniment_path = os.path.join(output_dir, base_name, 'accompaniment.wav')
    os.remove(accompaniment_path)
    os.rmdir(os.path.join(output_dir, base_name))

    print(f"Separated vocals to {new_vocals_path}")
    return new_vocals_path

# %%
# ฟังก์ชั่นสำหรับตัดไฟล์ .wav เป็นส่วนๆ
def split_wav_file(file_path, segment_length_ms, output_format, max_segments):
    if not file_path or not os.path.exists(file_path):
        print(f"File {file_path} does not exist.")
        return []
    
    # โหลดไฟล์เสียง
    audio = AudioSegment.from_file(file_path)
    if audio is None:
        print(f"Failed to load audio file: {file_path}")
        return []

    # คำนวณจำนวนไฟล์ที่จะได้รับจากการตัด
    num_segments = min(len(audio) // segment_length_ms, max_segments)
    segment_files = []

    # กำหนดความยาวของหมายเลข segment ตามจำนวน segments ที่มีสูงสุด
    num_length = len(str(num_segments))

    # ตัดและบันทึกแต่ละส่วน
    for i in range(num_segments):
        start_ms = i * segment_length_ms
        end_ms = start_ms + segment_length_ms
        segment = audio[start_ms:end_ms]

        # สร้างชื่อไฟล์สำหรับแต่ละส่วน
        segment_file_name = f"{file_path[:-4]}_segment_{str(i+1).zfill(num_length)}.{output_format}"

        # บันทึกส่วนของไฟล์เสียง
        segment.export(segment_file_name, format=output_format)
        print(f"Exported {segment_file_name}")
        segment_files.append(segment_file_name)

    return segment_files

# %%
# ฟังก์ชั่นสำหรับแปลงไฟล์ .wav จาก stereo เป็น mono
def convert_stereo_to_mono(file_path):
    if not file_path or not os.path.exists(file_path):
        print(f"File {file_path} does not exist.")
        return

    if file_path.endswith(".wav"):
        temp_file_path = file_path[:-4] + "_mono.wav"

        # ใช้ ffmpeg เพื่อแปลงไฟล์จาก stereo เป็น mono
        command = ["ffmpeg", "-i", file_path, "-ac", "1", temp_file_path]
        result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        
        if result.returncode != 0:
            print(f"Error converting {file_path} to mono:\n{result.stderr.decode('utf-8')}")

        # แทนที่ไฟล์เดิมด้วยไฟล์ที่แปลงแล้ว
        os.remove(file_path)
        os.rename(temp_file_path, file_path)

        print(f"Converted {file_path} to mono.")

# %%
# ฟังก์ชั่นสำหรับตรวจสอบว่าไฟล์ .wav เป็น mono หรือไม่
def check_mono_conversion(file_path):
    if not file_path or not os.path.exists(file_path):
        print(f"File {file_path} does not exist.")
        return False

    if file_path.endswith(".wav"):
        with wave.open(file_path, 'r') as wav_file:
            channels = wav_file.getnchannels()
            if channels != 1:
                print(f"File {file_path} has {channels} channels. Conversion failed.")
                return False
            else:
                print(f"File {file_path} is mono.")
                return True

# %%
# ฟังก์ชั่นหลักสำหรับการประมวลผลไฟล์เดียว
# def process_single_file(file_path):
#     # Step 1: Convert .mp3 to .wav if necessary
#     new_file_path = convert_mp3_to_wav(file_path)

#     if not new_file_path:
#         print("Conversion from mp3 to wav failed.")
#         return

#     # Step 2: Separate vocals using Spleeter
#     vocal_file_path = separate_vocals(new_file_path)

#     # Step 3: Split .wav file
#     segment_length_ms = 30 * 1000  # 30 วินาทีเป็นมิลลิวินาที
#     output_format = 'wav'  # หรือ 'mp3'
#     max_segments = 20  # สร้างไฟล์ตัดแยกได้สูงสุด 20 ไฟล์ต่อไฟล์ต้นฉบับ
#     segment_files = split_wav_file(vocal_file_path, segment_length_ms, output_format, max_segments)

#     # Step 4: Convert stereo .wav files to mono and check conversion
#     for segment_file in segment_files:
#         convert_stereo_to_mono(segment_file)
#         check_mono_conversion(segment_file)

#     # Step 5: Remove original files
#     if file_path.endswith('.mp3') and os.path.exists(file_path):
#         os.remove(file_path)
#         print(f"Original file {file_path} has been removed.")

#     if os.path.exists(new_file_path):
#         os.remove(new_file_path)
#         print(f"Original file {new_file_path} has been removed.")

#     if os.path.exists(vocal_file_path):
#         os.remove(vocal_file_path)
#         print(f"Original file {vocal_file_path} has been removed.") 
def process_single_file(file_path):
    # Step 1: Convert .mp3 to .wav if necessary
    new_file_path = convert_mp3_to_wav(file_path)

    if not new_file_path:
        print("Conversion from mp3 to wav failed.")
        return

    # Step 2: ไม่ต้องแยกเสียงร้องแล้ว

    # Step 3: Split .wav file
    segment_length_ms = 30 * 1000  # 30 วินาทีเป็นมิลลิวินาที
    output_format = 'wav'  # หรือ 'mp3'
    max_segments = 20  # สร้างไฟล์ตัดแยกได้สูงสุด 20 ไฟล์ต่อไฟล์ต้นฉบับ
    segment_files = split_wav_file(new_file_path, segment_length_ms, output_format, max_segments)

    # Step 4: Convert stereo .wav files to mono and check conversion
    for segment_file in segment_files:
        convert_stereo_to_mono(segment_file)
        check_mono_conversion(segment_file)

    # Step 5: Remove original files (ลบเฉพาะไฟล์ mp3 ต้นฉบับ)
    if file_path.endswith('.mp3') and os.path.exists(file_path):
        os.remove(file_path)
        print(f"Original file {file_path} has been removed.")

# %%
# ฟังก์ชั่นสำหรับถอดเสียงจากไฟล์เสียงโดยใช้ Google Cloud Speech-to-Text
def transcribe_audio(audio_file_path):
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../you_path_Key.json"
    client = speech.SpeechClient()

    with open(audio_file_path, "rb") as audio_file:
        content = audio_file.read()

    # ตรวจสอบว่าไฟล์เสียงไม่ว่างเปล่า
    if not content:
        print(f"Audio file is empty: {os.path.basename(audio_file_path)}")
        return None

    audio = speech.RecognitionAudio(content=content)
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=44100,  # 16000 44100 22050 48000
        language_code="th-TH",
    )

    try:
        response = client.recognize(config=config, audio=audio)
    except Exception as e:
        print(f"Error transcribing audio file: {os.path.basename(audio_file_path)}\n{str(e)}")
        return None

    transcript = ""
    for result in response.results:
        transcript += result.alternatives[0].transcript

    if not transcript:
        print(f"Failed to transcribe audio file: {os.path.basename(audio_file_path)}")
        return None

    return transcript

# %%
# ฟังก์ชั่นสำหรับโหลดคำจากไฟล์ JSON
def load_words(json_file_path):
    if not os.path.exists(json_file_path):
        raise FileNotFoundError(f"The file {json_file_path} does not exist.")
    
    with open(json_file_path, mode='r', encoding='utf-8-sig') as file: #utf-8-sig utf-8
        words = json.load(file)
    return words

# %%
# ตรวจสอบการมีอยู่ของไฟล์ JSON
negative_words_path = '../you_path'
positive_words_path = '../you_path'

if not os.path.exists(negative_words_path):
    raise FileNotFoundError(f"{negative_words_path} not found.")

if not os.path.exists(positive_words_path):
    raise FileNotFoundError(f"{positive_words_path} not found.")

# โหลดข้อมูลคำลบและคำบวกจากไฟล์ JSON
negative_words = load_words(negative_words_path)["Negative_word"]
positive_words = load_words(positive_words_path)["Positive_word"]

# %%
# ประเมิณความรู้สึก
def evaluate_sentiment(transcript, negative_words, positive_words):
    transcript_words = word_tokenize(transcript, engine="newmm")
    
    # สร้าง bigrams และ trigrams
    bigrams = [''.join(transcript_words[i:i+2]) for i in range(len(transcript_words)-1)]
    trigrams = [''.join(transcript_words[i:i+3]) for i in range(len(transcript_words)-2)]
    
    # รวม unigram, bigram, และ trigram
    combined_words = transcript_words + bigrams + trigrams
    
    negative_count = 0
    positive_count = 0

    # ลบการคำนวณคะแนน และเก็บเพียงจำนวนคำ
    for word in combined_words:
        if word in negative_words:
            negative_count += 1
        elif word in positive_words:
            positive_count += 1

    # ไม่คำนวณ total_score, negative_score, positive_score
    return negative_count, positive_count, combined_words

# %%
# ฟังก์ชั่นสำหรับลบไฟล์เสียงทั้งหมดในไดเรกทอรีที่กำหนด
def delete_all_audio_files(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.wav') or file.endswith('.mp3'):  # ลบทั้ง .wav และ .mp3
                file_path = os.path.join(root, file)
                try:
                    os.remove(file_path)
                    print(f"Deleted file: {file_path}")
                except Exception as e:
                    print(f"Failed to delete file: {file_path}. Reason: {str(e)}")

# %%
# ฟังก์ชั่นสำหรับประมวลผลไฟล์ .wav ทั้งหมดในไดเรกทอรี
def process_all_wav_files(directory):
    total_negative_count = 0
    total_positive_count = 0
    total_transcripts = []
    total_words_count = 0
    total_transcript = ""  # เพิ่มตัวแปร total_transcript

    for root, _, files in os.walk(directory):  # ไม่ใช้ตัวแปร dirs ดังนั้นใช้ _ แทน
        for file in files:
            if file.endswith('.wav'):
                audio_file_path = os.path.join(root, file)
                print(f"Processing file: {file}")  # พิมพ์ชื่อไฟล์เท่านั้น

                transcript = transcribe_audio(audio_file_path)
                if not transcript:
                    print(f"Skipping file due to transcription failure: {file}")
                    continue

                negative_count, positive_count, combined_words = evaluate_sentiment(
                    transcript, negative_words, positive_words)
                
                total_transcripts.append(transcript)
                total_transcript += transcript + " "  # รวม transcript ของแต่ละไฟล์
                total_negative_count += negative_count
                total_positive_count += positive_count
                total_words_count += len(combined_words)

                print(f"Tokenized Words: {combined_words}")
                print(f"Transcript: {transcript}")
                print(f"Negative Words Count: {negative_count}")
                print(f"Positive Words Count: {positive_count}")
                print()
                # # ลบไฟล์ชั่วคราวหลังการประมวลผล
                # os.remove(audio_file_path)

    total_transcripts_combined = ' '.join(total_transcripts)
    negative_percentage_total_words = (total_negative_count / total_words_count) * 100 if total_words_count > 0 else 0
    negative_percentage_positive_words = (total_negative_count / total_positive_count) * 100 if total_positive_count > 0 else 0

    is_negative_overall = (
        negative_percentage_total_words >= 30 or
        negative_percentage_positive_words >= 10
    )

    print("\n--- Summary ---")
    print(f"Total Negative Words Count: {total_negative_count}")
    print(f"Total Positive Words Count: {total_positive_count}")
    print(f"Total Negative Words Compared To Positive Words: {negative_percentage_positive_words:.2f}%")
    print(f"Total Negative Words Compared To Total Words: {negative_percentage_total_words:.2f}%")
    print(f"Is the overall sentiment negative? {'Yes' if is_negative_overall else 'No'}")
    print(f"Total Words Count: {total_words_count}")
    print(f"Total Transcript: {total_transcript}")
    print()

    # ลบไฟล์เสียงทั้งหมดในไดเรกทอรีหลังจากการประมวลผลทั้งหมดเสร็จสิ้น
    delete_all_audio_files(directory)

# %%
if __name__ == "__main__":
    # ตัวอย่างการใช้งาน
    file_path = r"../you_path"  # เปลี่ยนเป็นพาธของไฟล์ที่ต้องการ
    process_single_file(file_path)

    # ตัวอย่างการใช้งาน
    directory = '../you_directory'
    process_all_wav_files(directory)

    # ล้างหน่วยความจำเพื่อป้องกันปัญหาหน่วยความจำเกิน
    gc.collect()
# Out:
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_02.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_03.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_04.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_05.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_06.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_07.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_08.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_09.wav
# Exported D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_10.wav
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_02.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_02.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_03.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_03.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_04.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_04.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_05.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_05.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_06.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_06.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_07.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_07.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_08.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_08.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_09.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_09.wav is mono.
# Converted D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_10.wav to mono.
# File D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_10.wav is mono.
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited).wav
# Error transcribing audio file: อภิสิทธิ์ชน - COCKTAIL(edited).wav
# 400 Request payload size exceeds the limit: 10485760 bytes.
# Skipping file due to transcription failure: อภิสิทธิ์ชน - COCKTAIL(edited).wav
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav
# Failed to transcribe audio file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav
# Skipping file due to transcription failure: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_02.wav
# Tokenized Words: ['เช้า', 'ก็', 'เข้า', 'ไม่', 'ถึงขนาด', 'จิ๋ว', 'ได้มา', 'ถาม', 'ฉัน', 'รอ', 'อยู่', 'ใน', 'แถว', 'แล้วก็', 'มีเรื่อง', 'เธอ', 'ที่', 'ชื่อว่า', 'มี', 'ใคร', 'ก็แล้วแต่', 'เช้าก็', 'ก็เข้า', 'เข้าไม่', 'ไม่ถึงขนาด', 'ถึงขนาดจิ๋ว', 'จิ๋วได้มา', 'ได้มาถาม', 'ถามฉัน', 'ฉันรอ', 'รออยู่', 'อยู่ใน', 'ในแถว', 'แถวแล้วก็', 'แล้วก็มีเรื่อง', 'มีเรื่องเธอ', 'เธอที่', 'ที่ชื่อว่า', 'ชื่อว่ามี', 'มีใคร', 'ใครก็แล้วแต่', 'เช้าก็เข้า', 'ก็เข้าไม่', 'เข้าไม่ถึงขนาด', 'ไม่ถึงขนาดจิ๋ว', 'ถึงขนาดจิ๋วได้มา', 'จิ๋วได้มาถาม', 'ได้มาถามฉัน', 'ถามฉันรอ', 'ฉันรออยู่', 'รออยู่ใน', 'อยู่ในแถว', 'ในแถวแล้วก็', 'แถวแล้วก็มีเรื่อง', 'แล้วก็มีเรื่องเธอ', 'มีเรื่องเธอที่', 'เธอที่ชื่อว่า', 'ที่ชื่อว่ามี', 'ชื่อว่ามีใคร', 'มีใครก็แล้วแต่']
# Transcript: เช้าก็เข้าไม่ถึงขนาดจิ๋วได้มาถามฉันรออยู่ในแถวแล้วก็มีเรื่องเธอที่ชื่อว่ามีใครก็แล้วแต่
# Negative Words Count: 1
# Positive Words Count: 3
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_03.wav
# Tokenized Words: ['เลย', 'มี', 'คำถาม', 'เท่านั้น', 'เป็น', 'ใคร', 'มาจาก', 'ไหน', 'เธอ', 'ฉัน', 'ก็', 'คือ', 'เขา', 'ผิด', 'ปกป้อง', 'สิทธิ', 'ของ', 'ตัวเอง', 'ดู', 'นา', 'คน', 'ไม่', 'ทำ', 'เขา', 'ก็', 'ไม่', 'รู้', 'ว่า', 'เรา', 'เป็น', 'คน', 'ที่รัก', 'เธอ', 'เลยมี', 'มีคำถาม', 'คำถามเท่านั้น', 'เท่านั้นเป็น', 'เป็นใคร', 'ใครมาจาก', 'มาจากไหน', 'ไหนเธอ', 'เธอฉัน', 'ฉันก็', 'ก็คือ', 'คือเขา', 'เขาผิด', 'ผิดปกป้อง', 'ปกป้องสิทธิ', 'สิทธิของ', 'ของตัวเอง', 'ตัวเองดู', 'ดูนา', 'นาคน', 'คนไม่', 'ไม่ทำ', 'ทำเขา', 'เขาก็', 'ก็ไม่', 'ไม่รู้', 'รู้ว่า', 'ว่าเรา', 'เราเป็น', 'เป็นคน', 'คนที่รัก', 'ที่รักเธอ', 'เลยมีคำถาม', 'มีคำถามเท่านั้น', 'คำถามเท่านั้นเป็น', 'เท่านั้นเป็นใคร', 'เป็นใครมาจาก', 'ใครมาจากไหน', 'มาจากไหนเธอ', 'ไหนเธอฉัน', 'เธอฉันก็', 'ฉันก็คือ', 'ก็คือเขา', 'คือเขาผิด', 'เขาผิดปกป้อง', 'ผิดปกป้องสิทธิ', 'ปกป้องสิทธิของ', 'สิทธิของตัวเอง', 'ของตัวเองดู', 'ตัวเองดูนา', 'ดูนาคน', 'นาคนไม่', 'คนไม่ทำ', 'ไม่ทำเขา', 'ทำเขาก็', 'เขาก็ไม่', 'ก็ไม่รู้', 'ไม่รู้ว่า', 'รู้ว่าเรา', 'ว่าเราเป็น', 'เราเป็นคน', 'เป็นคนที่รัก', 'คนที่รักเธอ']
# Transcript: เลยมีคำถามเท่านั้นเป็นใครมาจากไหนเธอฉันก็คือเขาผิดปกป้องสิทธิของตัวเองดูนาคนไม่ทำเขาก็ไม่รู้ว่าเราเป็นคนที่รักเธอ
# Negative Words Count: 3
# Positive Words Count: 6
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_04.wav
# Tokenized Words: ['เดิน', 'กับ', 'ใคร', 'ก็', 'ไป', 'โรงเรียน', 'มาจาก', 'ไหน', 'ทำไม', 'ถึง', 'ชน', 'คน', 'คุณสมบัติ', 'เป็น', 'อย่างไร', 'ให้', 'รู้', 'ไว้', 'เขา', 'บอก', 'เดินกับ', 'กับใคร', 'ใครก็', 'ก็ไป', 'ไปโรงเรียน', 'โรงเรียนมาจาก', 'มาจากไหน', 'ไหนทำไม', 'ทำไมถึง', 'ถึงชน', 'ชนคน', 'คนคุณสมบัติ', 'คุณสมบัติเป็น', 'เป็นอย่างไร', 'อย่างไรให้', 'ให้รู้', 'รู้ไว้', 'ไว้เขา', 'เขาบอก', 'เดินกับใคร', 'กับใครก็', 'ใครก็ไป', 'ก็ไปโรงเรียน', 'ไปโรงเรียนมาจาก', 'โรงเรียนมาจากไหน', 'มาจากไหนทำไม', 'ไหนทำไมถึง', 'ทำไมถึงชน', 'ถึงชนคน', 'ชนคนคุณสมบัติ', 'คนคุณสมบัติเป็น', 'คุณสมบัติเป็นอย่างไร', 'เป็นอย่างไรให้', 'อย่างไรให้รู้', 'ให้รู้ไว้', 'รู้ไว้เขา', 'ไว้เขาบอก']
# Transcript: เดินกับใครก็ไปโรงเรียนมาจากไหนทำไมถึงชนคนคุณสมบัติเป็นอย่างไรให้รู้ไว้เขาบอก
# Negative Words Count: 1
# Positive Words Count: 5
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_05.wav
# Tokenized Words: ['ใคร', 'ใคร', 'ก็', 'เอาแต่ใจ', 'ของ', 'ตัวเอง', 'แค่', 'หนึ่ง', 'คน', 'เธอ', 'จะ', 'มอง', 'ไม่เป็นไร', 'คนเดียว', 'แต่', 'ใช้', 'ไม่', 'ไหว', 'เพราะ', 'บางที', 'ประเทศ', 'ไทย', 'จึง', 'ได้', 'แค่นี้', 'วันนี้', 'ยัง', 'ไม่', 'ได้', 'จริงๆ', 'ใครใคร', 'ใครก็', 'ก็เอาแต่ใจ', 'เอาแต่ใจของ', 'ของตัวเอง', 'ตัวเองแค่', 'แค่หนึ่ง', 'หนึ่งคน', 'คนเธอ', 'เธอจะ', 'จะมอง', 'มองไม่เป็นไร', 'ไม่เป็นไรคนเดียว', 'คนเดียวแต่', 'แต่ใช้', 'ใช้ไม่', 'ไม่ไหว', 'ไหวเพราะ', 'เพราะบางที', 'บางทีประเทศ', 'ประเทศไทย', 'ไทยจึง', 'จึงได้', 'ได้แค่นี้', 'แค่นี้วันนี้', 'วันนี้ยัง', 'ยังไม่', 'ไม่ได้', 'ได้จริงๆ', 'ใครใครก็', 'ใครก็เอาแต่ใจ', 'ก็เอาแต่ใจของ', 'เอาแต่ใจของตัวเอง', 'ของตัวเองแค่', 'ตัวเองแค่หนึ่ง', 'แค่หนึ่งคน', 'หนึ่งคนเธอ', 'คนเธอจะ', 'เธอจะมอง', 'จะมองไม่เป็นไร', 'มองไม่เป็นไรคนเดียว', 'ไม่เป็นไรคนเดียวแต่', 'คนเดียวแต่ใช้', 'แต่ใช้ไม่', 'ใช้ไม่ไหว', 'ไม่ไหวเพราะ', 'ไหวเพราะบางที', 'เพราะบางทีประเทศ', 'บางทีประเทศไทย', 'ประเทศไทยจึง', 'ไทยจึงได้', 'จึงได้แค่นี้', 'ได้แค่นี้วันนี้', 'แค่นี้วันนี้ยัง', 'วันนี้ยังไม่', 'ยังไม่ได้', 'ไม่ได้จริงๆ']
# Transcript: ใครใครก็เอาแต่ใจของตัวเองแค่หนึ่งคนเธอจะมองไม่เป็นไรคนเดียวแต่ใช้ไม่ไหวเพราะบางทีประเทศไทยจึงได้แค่นี้วันนี้ยังไม่ได้จริงๆ
# Negative Words Count: 1
# Positive Words Count: 2
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_06.wav
# Tokenized Words: ['สน', 'เป็น', 'คน', 'ไม่ต้อง', 'เขา', 'เขา', 'ไม่ต้อง', 'มี', 'อะไร', 'ก็ได้', 'ก่อน', 'ทน', 'ทน', 'เอา', 'เรา', 'ไป', 'ก็', 'ไป', 'เอา', 'มาจาก', 'ไหน', 'ทำไม', 'ใช้', 'คำพูด', 'พอ', 'สน', 'คน', 'มัน', 'ไม่', 'รู้', 'วัน', 'เขา', 'บอก', 'สนเป็น', 'เป็นคน', 'คนไม่ต้อง', 'ไม่ต้องเขา', 'เขาเขา', 'เขาไม่ต้อง', 'ไม่ต้องมี', 'มีอะไร', 'อะไรก็ได้', 'ก็ได้ก่อน', 'ก่อนทน', 'ทนทน', 'ทนเอา', 'เอาเรา', 'เราไป', 'ไปก็', 'ก็ไป', 'ไปเอา', 'เอามาจาก', 'มาจากไหน', 'ไหนทำไม', 'ทำไมใช้', 'ใช้คำพูด', 'คำพูดพอ', 'พอสน', 'สนคน', 'คนมัน', 'มันไม่', 'ไม่รู้', 'รู้วัน', 'วันเขา', 'เขาบอก', 'สนเป็นคน', 'เป็นคนไม่ต้อง', 'คนไม่ต้องเขา', 'ไม่ต้องเขาเขา', 'เขาเขาไม่ต้อง', 'เขาไม่ต้องมี', 'ไม่ต้องมีอะไร', 'มีอะไรก็ได้', 'อะไรก็ได้ก่อน', 'ก็ได้ก่อนทน', 'ก่อนทนทน', 'ทนทนเอา', 'ทนเอาเรา', 'เอาเราไป', 'เราไปก็', 'ไปก็ไป', 'ก็ไปเอา', 'ไปเอามาจาก', 'เอามาจากไหน', 'มาจากไหนทำไม', 'ไหนทำไมใช้', 'ทำไมใช้คำพูด', 'ใช้คำพูดพอ', 'คำพูดพอสน', 'พอสนคน', 'สนคนมัน', 'คนมันไม่', 'มันไม่รู้', 'ไม่รู้วัน', 'รู้วันเขา', 'วันเขาบอก']
# Transcript: สนเป็นคนไม่ต้องเขาเขาไม่ต้องมีอะไรก็ได้ก่อนทนทนเอาเราไปก็ไปเอามาจากไหนทำไมใช้คำพูดพอสนคนมันไม่รู้วันเขาบอก
# Negative Words Count: 4
# Positive Words Count: 6
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_07.wav
# Tokenized Words: ['ฉัน']
# Transcript: ฉัน
# Negative Words Count: 0
# Positive Words Count: 0
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_08.wav
# Tokenized Words: ['แซงคิว', 'ผม', 'ทำไม', ' ', 'assertion', ' ', 'เป็น', 'คน', 'ไม่', 'รัก', 'เขา', 'ก็', 'ไม่', 'ได้', 'กอด', 'คน', 'มีปัญหา', 'เข้ามา', 'ทีหลัง', 'แต่ก่อน', 'เป็น', 'ลูกเต้า', 'เหล่า', 'ใคร', 'แซงคิวผม', 'ผมทำไม', 'ทำไม ', ' assertion', 'assertion ', ' เป็น', 'เป็นคน', 'คนไม่', 'ไม่รัก', 'รักเขา', 'เขาก็', 'ก็ไม่', 'ไม่ได้', 'ได้กอด', 'กอดคน', 'คนมีปัญหา', 'มีปัญหาเข้ามา', 'เข้ามาทีหลัง', 'ทีหลังแต่ก่อน', 'แต่ก่อนเป็น', 'เป็นลูกเต้า', 'ลูกเต้าเหล่า', 'เหล่าใคร', 'แซงคิวผมทำไม', 'ผมทำไม ', 'ทำไม assertion', ' assertion ', 'assertion เป็น', ' เป็นคน', 'เป็นคนไม่', 'คนไม่รัก', 'ไม่รักเขา', 'รักเขาก็', 'เขาก็ไม่', 'ก็ไม่ได้', 'ไม่ได้กอด', 'ได้กอดคน', 'กอดคนมีปัญหา', 'คนมีปัญหาเข้ามา', 'มีปัญหาเข้ามาทีหลัง', 'เข้ามาทีหลังแต่ก่อน', 'ทีหลังแต่ก่อนเป็น', 'แต่ก่อนเป็นลูกเต้า', 'เป็นลูกเต้าเหล่า', 'ลูกเต้าเหล่าใคร']
# Transcript: แซงคิวผมทำไม assertion เป็นคนไม่รักเขาก็ไม่ได้กอดคนมีปัญหาเข้ามาทีหลังแต่ก่อนเป็นลูกเต้าเหล่าใคร
# Negative Words Count: 0
# Positive Words Count: 4
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_09.wav
# Tokenized Words: ['โทร', 'ไป', 'เล่าเรียน', 'มาจาก', 'ไหน', 'ทำไม', 'ใจ', 'เขา', 'ยิง', 'ปื่น', 'คอร์ด', 'คน', 'ไม่', 'ถึง', 'เขา', 'ก็', 'ไม่', 'รู้อยู่', 'ใน', 'ตรง', 'แล้ว', 'อะไร', 'อะไร', 'ต้อง', 'ได้', 'มอง', 'ตน', 'เป็น', 'คน', 'มีปัญหา', 'ก็', 'ไม่', 'เอา', 'เรา', 'ไป', 'ก็', 'ไม่', 'รับ', 'โทรไป', 'ไปเล่าเรียน', 'เล่าเรียนมาจาก', 'มาจากไหน', 'ไหนทำไม', 'ทำไมใจ', 'ใจเขา', 'เขายิง', 'ยิงปื่น', 'ปื่นคอร์ด', 'คอร์ดคน', 'คนไม่', 'ไม่ถึง', 'ถึงเขา', 'เขาก็', 'ก็ไม่', 'ไม่รู้อยู่', 'รู้อยู่ใน', 'ในตรง', 'ตรงแล้ว', 'แล้วอะไร', 'อะไรอะไร', 'อะไรต้อง', 'ต้องได้', 'ได้มอง', 'มองตน', 'ตนเป็น', 'เป็นคน', 'คนมีปัญหา', 'มีปัญหาก็', 'ก็ไม่', 'ไม่เอา', 'เอาเรา', 'เราไป', 'ไปก็', 'ก็ไม่', 'ไม่รับ', 'โทรไปเล่าเรียน', 'ไปเล่าเรียนมาจาก', 'เล่าเรียนมาจากไหน', 'มาจากไหนทำไม', 'ไหนทำไมใจ', 'ทำไมใจเขา', 'ใจเขายิง', 'เขายิงปื่น', 'ยิงปื่นคอร์ด', 'ปื่นคอร์ดคน', 'คอร์ดคนไม่', 'คนไม่ถึง', 'ไม่ถึงเขา', 'ถึงเขาก็', 'เขาก็ไม่', 'ก็ไม่รู้อยู่', 'ไม่รู้อยู่ใน', 'รู้อยู่ในตรง', 'ในตรงแล้ว', 'ตรงแล้วอะไร', 'แล้วอะไรอะไร', 'อะไรอะไรต้อง', 'อะไรต้องได้', 'ต้องได้มอง', 'ได้มองตน', 'มองตนเป็น', 'ตนเป็นคน', 'เป็นคนมีปัญหา', 'คนมีปัญหาก็', 'มีปัญหาก็ไม่', 'ก็ไม่เอา', 'ไม่เอาเรา', 'เอาเราไป', 'เราไปก็', 'ไปก็ไม่', 'ก็ไม่รับ']
# Transcript: โทรไปเล่าเรียนมาจากไหนทำไมใจเขายิงปื่นคอร์ดคนไม่ถึงเขาก็ไม่รู้อยู่ในตรงแล้วอะไรอะไรต้องได้มองตนเป็นคนมีปัญหาก็ไม่เอาเราไปก็ไม่รับ
# Negative Words Count: 4
# Positive Words Count: 5
#
# Processing file: อภิสิทธิ์ชน - COCKTAIL(edited)_segment_10.wav
# Tokenized Words: ['คอร์ด', 'เพลง', 'คน', 'ไหน', 'คน', 'นั้น', 'เป็น', 'อย่างไร', 'ให้', 'รู้', 'ว่า', 'ให้', 'เขา', 'บ่น', 'คอร์ดเพลง', 'เพลงคน', 'คนไหน', 'ไหนคน', 'คนนั้น', 'นั้นเป็น', 'เป็นอย่างไร', 'อย่างไรให้', 'ให้รู้', 'รู้ว่า', 'ว่าให้', 'ให้เขา', 'เขาบ่น', 'คอร์ดเพลงคน', 'เพลงคนไหน', 'คนไหนคน', 'ไหนคนนั้น', 'คนนั้นเป็น', 'นั้นเป็นอย่างไร', 'เป็นอย่างไรให้', 'อย่างไรให้รู้', 'ให้รู้ว่า', 'รู้ว่าให้', 'ว่าให้เขา', 'ให้เขาบ่น']
# Transcript: คอร์ดเพลงคนไหนคนนั้นเป็นอย่างไรให้รู้ว่าให้เขาบ่น
# Negative Words Count: 1
# Positive Words Count: 4
#
#
# --- Summary ---
# Total Negative Words Count: 15
# Total Positive Words Count: 35
# Total Negative Words Compared To Positive Words: 42.86%
# Total Negative Words Compared To Total Words: 2.44%
# Is the overall sentiment negative? Yes
# Total Words Count: 616
# Total Transcript: เช้าก็เข้าไม่ถึงขนาดจิ๋วได้มาถามฉันรออยู่ในแถวแล้วก็มีเรื่องเธอที่ชื่อว่ามีใครก็แล้วแต่ เลยมีคำถามเท่านั้นเป็นใครมาจากไหนเธอฉันก็คือเขาผิดปกป้องสิทธิของตัวเองดูนาคนไม่ทำเขาก็ไม่รู้ว่าเราเป็นคนที่รักเธอ เดินกับใครก็ไปโรงเรียนมาจากไหนทำไมถึงชนคนคุณสมบัติเป็นอย่างไรให้รู้ไว้เขาบอก ใครใครก็เอาแต่ใจของตัวเองแค่หนึ่งคนเธอจะมองไม่เป็นไรคนเดียวแต่ใช้ไม่ไหวเพราะบางทีประเทศไทยจึงได้แค่นี้วันนี้ยังไม่ได้จริงๆ สนเป็นคนไม่ต้องเขาเขาไม่ต้องมีอะไรก็ได้ก่อนทนทนเอาเราไปก็ไปเอามาจากไหนทำไมใช้คำพูดพอสนคนมันไม่รู้วันเขาบอก ฉัน แซงคิวผมทำไม assertion เป็นคนไม่รักเขาก็ไม่ได้กอดคนมีปัญหาเข้ามาทีหลังแต่ก่อนเป็นลูกเต้าเหล่าใคร โทรไปเล่าเรียนมาจากไหนทำไมใจเขายิงปื่นคอร์ดคนไม่ถึงเขาก็ไม่รู้อยู่ในตรงแล้วอะไรอะไรต้องได้มองตนเป็นคนมีปัญหาก็ไม่เอาเราไปก็ไม่รับ คอร์ดเพลงคนไหนคนนั้นเป็นอย่างไรให้รู้ว่าให้เขาบ่น
#
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited).wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_01.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_02.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_03.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_04.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_05.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_06.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_07.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_08.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_09.wav
# Deleted file: D:\Project\DataSet\Data_แค่ที่จำเป็น\ทดสอบ\For_Test\เทสอีกรอบ\อภิสิทธิ์ชน - COCKTAIL(edited)_segment_10.wav
